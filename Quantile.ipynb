# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import median_absolute_error as mae
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('autos_new.csv')
df.head(n=10)
# Out:
#   date_crawled                                               name  \
# 0   2016-03-24                               A5_Sportback_2.7_Tdi
# 1   2016-03-14                     Jeep_Grand_Cherokee_"Overland"
# 2   2016-03-17                                 GOLF_4_1_4__3TÜRER
# 3   2016-03-31                     Skoda_Fabia_1.4_TDI_PD_Classic
# 4   2016-04-04  BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...
# 5   2016-04-01                        Peugeot_206_CC_110_Platinum
# 6   2016-04-04               Ford_C___Max_Titanium_1_0_L_EcoBoost
# 7   2016-03-17  VW_Golf_4_5_tuerig_zu_verkaufen_mit_Anhaengerk...
# 8   2016-03-26                                  Mazda_3_1.6_Sport
# 9   2016-04-07      Volkswagen_Passat_Variant_2.0_TDI_Comfortline
#
#    dollar_price   vehicle_type  registration_year    gearbox  power_ps  \
# 0         18300          coupé               2011    manuell       190
# 1          9800            NaN               2004  automatik       163
# 2          1500      small car               2001    manuell        75
# 3          3600      small car               2008    manuell        69
# 4           650      limousine               1995    manuell       102
# 5          2200    convertible               2004    manuell       109
# 6         14500            bus               2014    manuell       125
# 7           999      small car               1998    manuell       101
# 8          2000      limousine               2004    manuell       105
# 9          2799  station wagon               2005    manuell       140
#
#      model  kilometer  registration_month fuel_type       brand  \
# 0      NaN     125000                   5    diesel        audi
# 1    grand     125000                   8    diesel        jeep
# 2     golf     150000                   6  gasoline  volkswagen
# 3    fabia      90000                   7    diesel       skoda
# 4      3er     150000                  10  gasoline         bmw
# 5  2_reihe     150000                   8  gasoline     peugeot
# 6    c_max      30000                   8  gasoline        ford
# 7     golf     150000                   0       NaN  volkswagen
# 8  3_reihe     150000                  12  gasoline       mazda
# 9   passat     150000                  12    diesel  volkswagen
#
#   unrepaired_damage  ad_created  postal_code last_seen_online
# 0                ja  2016-03-24        66954       2016-04-07
# 1               NaN  2016-03-14        90480       2016-04-05
# 2              nein  2016-03-17        91074       2016-03-17
# 3              nein  2016-03-31        60437       2016-04-06
# 4                ja  2016-04-04        33775       2016-04-06
# 5              nein  2016-04-01        67112       2016-04-05
# 6               NaN  2016-04-04        94505       2016-04-04
# 7               NaN  2016-03-17        27472       2016-03-31
# 8              nein  2016-03-26        96224       2016-04-06
# 9                ja  2016-04-07        57290       2016-04-07

# %%
col=df.columns
print(type(col))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
# drop_col=['date_crawled','name']
df.drop(['date_crawled','name','ad_created','last_seen_online'],axis=1,inplace=True)
df.head()
# Out:
#    dollar_price vehicle_type  registration_year    gearbox  power_ps  model  \
# 0         18300        coupé               2011    manuell       190    NaN
# 1          9800          NaN               2004  automatik       163  grand
# 2          1500    small car               2001    manuell        75   golf
# 3          3600    small car               2008    manuell        69  fabia
# 4           650    limousine               1995    manuell       102    3er
#
#    kilometer  registration_month fuel_type       brand unrepaired_damage  \
# 0     125000                   5    diesel        audi                ja
# 1     125000                   8    diesel        jeep               NaN
# 2     150000                   6  gasoline  volkswagen              nein
# 3      90000                   7    diesel       skoda              nein
# 4     150000                  10  gasoline         bmw                ja
#
#    postal_code
# 0        66954
# 1        90480
# 2        91074
# 3        60437
# 4        33775

# %%
df.describe()
# Out:
#         dollar_price  registration_year       power_ps      kilometer  \
# count  335111.000000      335111.000000  335111.000000  335111.000000
# mean     6291.242606        2003.733148     120.694191  125235.354853
# std      8608.259613           7.272514     190.797297   39612.753443
# min       500.000000        1945.000000       0.000000    5000.000000
# 25%      1500.000000        2000.000000      75.000000  100000.000000
# 50%      3500.000000        2004.000000     110.000000  150000.000000
# 75%      7900.000000        2008.000000     150.000000  150000.000000
# max    245000.000000        2016.000000   20000.000000  150000.000000
#
#        registration_month    postal_code
# count       335111.000000  335111.000000
# mean             5.924986   51269.627368
# std              3.631074   25714.890506
# min              0.000000    1067.000000
# 25%              3.000000   30952.000000
# 50%              6.000000   50226.000000
# 75%              9.000000   72124.000000
# max             12.000000   99998.000000

# %%
data=np.array(df)

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 235829 entries, 2 to 335110
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   dollar_price        235829 non-null  int64
#  1   vehicle_type        235829 non-null  object
#  2   registration_year   235829 non-null  int64
#  3   gearbox             235829 non-null  object
#  4   power_ps            235829 non-null  int64
#  5   model               235829 non-null  object
#  6   kilometer           235829 non-null  int64
#  7   registration_month  235829 non-null  int64
#  8   fuel_type           235829 non-null  object
#  9   brand               235829 non-null  object
#  10  unrepaired_damage   235829 non-null  object
#  11  postal_code         235829 non-null  int64
# dtypes: int64(6), object(6)
# memory usage: 23.4+ MB

# %%
pd.DataFrame(X).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235829 entries, 0 to 235828
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       235829 non-null  float32
#  1   1       235829 non-null  float32
#  2   2       235829 non-null  float32
#  3   3       235829 non-null  float32
#  4   4       235829 non-null  float32
#  5   5       235829 non-null  float32
#  6   6       235829 non-null  float32
#  7   7       235829 non-null  float32
#  8   8       235829 non-null  float32
#  9   9       235829 non-null  float32
#  10  10      235829 non-null  float32
# dtypes: float32(11)
# memory usage: 9.9 MB

# %%
df.to_csv("autos_modified.csv")

# %%
df.reset_index(drop=True,inplace=True)
df.head(n=15)
# print(type(ds))
# Out:
#     dollar_price   vehicle_type  registration_year    gearbox  power_ps  \
# 0           1500      small car               2001    manuell        75
# 1           3600      small car               2008    manuell        69
# 2            650      limousine               1995    manuell       102
# 3           2200    convertible               2004    manuell       109
# 4           2000      limousine               2004    manuell       105
# 5           2799  station wagon               2005    manuell       140
# 6           1750      small car               2004  automatik        75
# 7           7550            bus               2007    manuell       136
# 8           1850            bus               2004    manuell       102
# 9          10400          coupé               2009    manuell       160
# 10          3699      limousine               2002  automatik       231
# 11           500      limousine               1990    manuell       118
# 12          2500  station wagon               2002  automatik       193
# 13          6900      limousine               2008    manuell        99
# 14          1990            bus               1981    manuell        50
#
#           model  kilometer  registration_month fuel_type          brand  \
# 0          golf     150000                   6  gasoline     volkswagen
# 1         fabia      90000                   7    diesel          skoda
# 2           3er     150000                  10  gasoline            bmw
# 3       2_reihe     150000                   8  gasoline        peugeot
# 4       3_reihe     150000                  12  gasoline          mazda
# 5        passat     150000                  12    diesel     volkswagen
# 6        twingo     150000                   2  gasoline        renault
# 7         c_max     150000                   6    diesel           ford
# 8      a_klasse     150000                   1  gasoline  mercedes_benz
# 9      scirocco     100000                   4  gasoline     volkswagen
# 10          5er     150000                   7  gasoline            bmw
# 11       andere     150000                  10  gasoline  mercedes_benz
# 12          5er     150000                   9    diesel            bmw
# 13        civic      60000                  11  gasoline          honda
# 14  transporter       5000                   1  gasoline     volkswagen
#
#    unrepaired_damage  postal_code
# 0               nein        91074
# 1               nein        60437
# 2                 ja        33775
# 3               nein        67112
# 4               nein        96224
# 5                 ja        57290
# 6               nein        65599
# 7               nein        88361
# 8               nein        49565
# 9               nein        75365
# 10              nein        68309
# 11                ja        35390
# 12                ja        73765
# 13              nein        12621
# 14              nein        87471

# %%
le = LabelEncoder()
#Applies transformation on each columns
ds = df.apply(le.fit_transform)

# %%
ds
# Out:
#         dollar_price  vehicle_type  registration_year  gearbox  power_ps  \
# 0                373             5                 53        1        73
# 1                937             5                 60        1        67
# 2                 66             3                 47        1       100
# 3                570             1                 56        1       107
# 4                526             3                 56        1       103
# ...              ...           ...                ...      ...       ...
# 235824           836             3                 56        1       223
# 235825           248             0                 52        1         0
# 235826           266             1                 52        0        99
# 235827          2001             0                 48        1       100
# 235828          3676             3                 65        1       311
#
#         model  kilometer  registration_month  fuel_type  brand  \
# 0         114         12                   6          2     37
# 1         100          9                   7          1     31
# 2          11         12                  10          2      2
# 3           8         12                   8          2     25
# 4          10         12                  12          2     19
# ...       ...        ...                 ...        ...    ...
# 235824    137         12                   5          2     30
# 235825    239         12                   3          2     24
# 235826    105         11                   3          2     32
# 235827    215         12                   3          1     37
# 235828    143          5                   8          2      2
#
#         unrepaired_damage  postal_code
# 0                       1         6953
# 1                       1         4157
# 2                       0         2331
# 3                       1         4579
# 4                       1         7665
# ...                   ...          ...
# 235824                  0         7699
# 235825                  1         1823
# 235826                  1         1785
# 235827                  1         6561
# 235828                  1         5111
#
# [235829 rows x 12 columns]

# %%
lossl = []

# %%
class MyModel(torch.nn.Module):
    def __init__(self):
        super(MyModel,self).__init__()
        #self.linear_yq1_output = torch.nn.Linear(30,1)
        #self.linear_yq2_output = torch.nn.Linear(30,1)
        #self.linear_yq3_output = torch.nn.Linear(30,1)

        self.net = torch.nn.Sequential(
        torch.nn.Linear(11, 30),
        torch.nn.LeakyReLU(),
        #torch.nn.Tanh(),
        
        torch.nn.Linear(30, 30),
        torch.nn.LeakyReLU(),
            
        torch.nn.Linear(30,3)

        #torch.nn.Tanh(),
        )

    def forward(self,x):
        return self.net(x)
    
modelA = MyModel()
modelA = modelA.cuda()

optimizer = torch.optim.Adam(params=modelA.parameters(), lr=0.005)

def criterion(input, target):
    ## Other Losses
    # Normal loss
    #loss = (((input[0] - target)/torch.exp(input[1]))**2+input[1]).mean()
    # Laplace loss
    #loss = (torch.abs((input[0] - target)/torch.exp(input[1]))+input[1]).mean()
    # t-distribution loss
    #nu = 3
    #loss = ((nu + 1)/2*torch.log(1+((input[0] - target)/torch.exp(input[1]))**2/nu)+input[1]).mean()
    # print(input, target)

    ## Quanile Loss
    q1 = 0.20
    q2 = 0.5
    q3 = 0.80
    

    ## Keras quantile loss, https://www.evergreeninnovations.co/blog-quantile-loss-function-for-machine-learning/    
    #e = y_p-y    
    #return tf.keras.backend.mean(tf.keras.backend.maximum(q*e, (q-1)*e))

    ## Quantile Loss
    ## for q1, q2, q3
    #print(input.shape)
    #print(input[:,0:1].shape)
#     print(yqs.shape)
    e1 = input[:, 0] - target # !!! if input[:,0]  -> shape = (1000,)
    e2 = input[:, 1] - target
    e3 = input[:, 2] - target
    eq1 = torch.max(q1*e1, (q1-1)*e1)
    eq2 = torch.max(q2*e2, (q2-1)*e2)
    eq3 = torch.max(q3*e3, (q3-1)*e3)
    
    #eq1 = torch.max(0.05*e1, (0.05-1)*e1)
    #eq2 = torch.max(0.5*e2, (0.5-1)*e2)
    #eq3 = torch.max(0.95*e3, (0.95-1)*e3)

    loss = (eq1 + eq2 + eq3).mean()

    return loss
    
train_x_tr = train_x_tr.cuda()    
train_y_tr = train_y_tr.cuda()

for step in range(6000):
    #yq1, yq2, yq3 = model(x)
    #loss = criterion(input=(yq1, yq2, yq3), target=y)
    yqs = modelA(train_x_tr)
    loss = criterion(input=yqs, target =train_y_tr)
    lossl.append(loss)
    #print(yqs.shape, train_y_tr.shape)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (step+1) % 1000 == 0:
        """
        Show your intermediate results
        """
        print('epoch {} loss={:.4}'.format(step+1, loss.data.item()))
        pass
# Out:
# epoch 1000 loss=466.9
# epoch 2000 loss=446.4
# epoch 3000 loss=436.4
# epoch 4000 loss=432.8
# epoch 5000 loss=418.0
# epoch 6000 loss=411.0

# %%
import torch

# %%
X = np.array(ds.iloc[:, 1:])
Y = np.array(ds.iloc[:, 0])
X = X.astype("float32")
Y = Y.astype("float32")
X
# Out:
# array([[5.000e+00, 5.300e+01, 1.000e+00, ..., 3.700e+01, 1.000e+00,
#         6.953e+03],
#        [5.000e+00, 6.000e+01, 1.000e+00, ..., 3.100e+01, 1.000e+00,
#         4.157e+03],
#        [3.000e+00, 4.700e+01, 1.000e+00, ..., 2.000e+00, 0.000e+00,
#         2.331e+03],
#        ...,
#        [1.000e+00, 5.200e+01, 0.000e+00, ..., 3.200e+01, 1.000e+00,
#         1.785e+03],
#        [0.000e+00, 4.800e+01, 1.000e+00, ..., 3.700e+01, 1.000e+00,
#         6.561e+03],
#        [3.000e+00, 6.500e+01, 1.000e+00, ..., 2.000e+00, 1.000e+00,
#         5.111e+03]], dtype=float32)

# %%
from sklearn.model_selection import train_test_split
train_x_tr, X_test, train_y_tr, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)
train_x_tr=torch.from_numpy(train_x_tr)
train_y_tr=torch.from_numpy(train_y_tr)
test_x_tr = torch.from_numpy(X_test)
test_y_tr = torch.from_numpy(y_test)
train_x_tr
# Out:
# tensor([[5.0000e+00, 4.8000e+01, 1.0000e+00,  ..., 3.7000e+01, 1.0000e+00,
#          2.7110e+03],
#         [0.0000e+00, 5.4000e+01, 0.0000e+00,  ..., 1.0000e+01, 1.0000e+00,
#          5.1960e+03],
#         [3.0000e+00, 5.8000e+01, 1.0000e+00,  ..., 2.0000e+00, 1.0000e+00,
#          3.4830e+03],
#         ...,
#         [6.0000e+00, 5.7000e+01, 1.0000e+00,  ..., 1.0000e+00, 1.0000e+00,
#          4.8800e+02],
#         [5.0000e+00, 4.8000e+01, 1.0000e+00,  ..., 9.0000e+00, 1.0000e+00,
#          3.6210e+03],
#         [1.0000e+00, 5.2000e+01, 1.0000e+00,  ..., 1.0000e+00, 1.0000e+00,
#          6.3590e+03]])

# %%
train_x_tr.shape
# Out:
# torch.Size([158005, 11])

# %%
y_pred = modelA(test_x_tr.cuda())

# %%
y_pred
# Out:
# tensor([[ 356.4010,  179.1604,   69.1811],
#         [2300.7666, 1930.8948, 1491.5920],
#         [1067.7211,  724.7874,  425.6036],
#         ...,
#         [1446.4659, 1094.5457,  731.3562],
#         [ 546.4516,  317.9315,  163.2609],
#         [ 686.1302,  491.0677,  308.3678]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)

# %%
test_y_tr
# Out:
# tensor([ 128., 1961.,  163.,  ...,  735.,  208.,  660.])

# %%
y_pred_array = np.array(test_y_tr)
y_pred_array
# Out:
# array([ 128., 1961.,  163., ...,  735.,  208.,  660.], dtype=float32)

# %%
predictions = y_pred.detach().cpu().numpy()
predictions
# Out:
# array([[ 356.40103,  179.16037,   69.18105],
#        [2300.7666 , 1930.8948 , 1491.592  ],
#        [1067.7211 ,  724.7874 ,  425.60364],
#        ...,
#        [1446.466  , 1094.5457 ,  731.3562 ],
#        [ 546.4516 ,  317.9315 ,  163.26093],
#        [ 686.13025,  491.06772,  308.36783]], dtype=float32)

# %%
predictions_mean = predictions[:, 1]

# %%
predictions_mean
# Out:
# array([ 179.16037, 1930.8948 ,  724.7874 , ..., 1094.5457 ,  317.9315 ,
#         491.06772], dtype=float32)

# %%
y_pred_array
# Out:
# array([ 128., 1961.,  163., ...,  735.,  208.,  660.], dtype=float32)

# %%
lossl = [x.detach().cpu().numpy() for x in lossl]

# %%
lossl = np.array(lossl)
ind = [i for i in range(1, lossl.shape[0]+1)]
plt.plot(ind, lossl)

# %%
mae(predictions_mean, y_pred_array)
# Out:
# 275.45422
